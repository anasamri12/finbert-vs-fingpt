# %% [markdown]
# ## News Scraping from Malaysian News

# %% [markdown]
# ## Install and import required libraries

# %%
# !pip install newspaper3k
# !pip install autoscraper
# !pip install requests

# %%
import pandas as pd
from autoscraper import AutoScraper
from bs4 import BeautifulSoup
import requests

# %%
from news_scraper import (
    build_requested_malaysia_site_configs,
    collect_multiple_sites,
    save_articles_csv,
)

configs = build_requested_malaysia_site_configs()
rows = collect_multiple_sites(configs, start_date="2023-01-01", max_articles_per_site=None)
save_articles_csv(rows, "malaysia_news_since_2023.csv")
print("Total rows:", len(rows))
# Out:
# [malaysiakini_news] Cutoff date: 2026-01-20
# [malaysiakini_news] HTML list pages yielded 0 unique links
# [malaysiakini_news] API offset 1: +32 new links (total 32)
# [malaysiakini_news] API offset 2: +32 new links (total 64)
# [malaysiakini_news] API offset 3: +32 new links (total 96)
# [malaysiakini_news] API offset 4: +32 new links (total 128)
# [malaysiakini_news] API offset 5: +32 new links (total 160)
# [malaysiakini_news] API offset 6: +32 new links (total 192)
# [malaysiakini_news] API offset 7: +32 new links (total 224)
# [malaysiakini_news] API offset 8: +32 new links (total 256)
# [malaysiakini_news] API offset 9: +32 new links (total 288)
# [malaysiakini_news] API offset 10: +32 new links (total 320)
# [malaysiakini_news] API offset 11: +32 new links (total 352)
# [malaysiakini_news] API offset 12: +32 new links (total 384)
# [malaysiakini_news] API offset 13: +32 new links (total 416)
# [malaysiakini_news] API offset 14: +32 new links (total 448)
# ...
